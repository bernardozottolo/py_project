# %%
import pandas as pd

# %%
file = 'empresaABC.xlsx'
df = pd.read_excel(file)
df.head()
# Out:
#    Coluna1 Responsável pelo acionamento ABC Data da validação do orçamento  \
# 0        1                            Maria                     2024-07-02
# 1        2                            Maria                            NaT
# 2        3                            Maria                     2024-07-02
# 3        4                            Maria                     2024-07-17
# 4        5                            Maria                     2024-07-16
#
#                       ITEM LPU  ITEM LPU2  \
# 0   nº 36, 56, 57, 17 e 75. \n    17486.0
# 1   nº 38, 56, 57, 17 e 75. \n    31831.0
# 2            nº 57, 17 e 40.\n     7260.0
# 3            nº 57, 17 e 40.\n     7260.0
# 4                        nº 17     3650.0
#
#                                          Contratação  \
# 0  Aprovação de projeto (LE) + Licença do Corpo d...
# 1  Aprovação de projeto (LE) + Licença do Corpo d...
# 2  Emissão do CA /assinatura da declaração  do re...
# 3  Emissão do CA /assinatura da declaração  do re...
# 4             Laudo Circunstanciado com ART do laudo
#
#                       Previsão estimado de Conclusão Identificação  \
# 0  Entrega do projeto: 31/07/2024. \n6 meses p/ L...         A1122
# 1                                                NaN         A7722
# 2   Entrega do Laudo Circunst. 08/08/2024.\n6 mes...         A6250
# 3   Entrega do Laudo Circunst. 08/08/2024.\n6 mes...         A6254
# 4                                2024-07-25 00:00:00         A9180
#
#                     Denominação                      Endereço   ...  \
# 0      Centro Operacional Alpha        Rua Nova Esperança, 123  ...
# 1             Estação Nova Vila         Avenida Horizonte, 456  ...
# 2  Terminal Logístico Horizonte   Estrada do Sol Nascente, 789  ...
# 3              Armazém Planalto         Rua das Palmeiras, 321  ...
# 4             Polo Estrela Azul  Avenida Estrela do Norte, 654  ...
#
#   Data do Protocolo       Nº do Protocolo  Data do Envio do Protocolo p/ ABC  \
# 0         2024-08-13  E45/58231/25634/2025                        2024-08-13
# 1                NaT                   NaN                               NaT
# 2                NaT                   NaN                               NaT
# 3                NaT                   NaN                               NaT
# 4                NaT                   NaN                               NaT
#
#   Código de Consulta site CBMERJ   \
# 0                        MTN5UTNI
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#   Batalhão Responsável\n ( Telefone e responsável) Exigência  (Sim/Não)  \
# 0                            DGST \n(21) 9876-5432                  NaN
# 1                                              NaN                  NaN
# 2                                              NaN                  NaN
# 3                                              NaN                  NaN
# 4                                              NaN                  NaN
#
#    Data da Exigência e prazo p/ Cumprir Observações   \
# 0                                   NaN          NaN
# 1                                   NaN          NaN
# 2                                   NaN          NaN
# 3                                   NaN          NaN
# 4                                   NaN          NaN
#
#   Data da conclusão do acionamento    \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                2024-07-25 00:00:00
#
#                                         Atualização
# 0  16/08/2024 - ABC confirma envio dos documentos...
# 1  12/08/2024 - Emitido alvará provisório referen...
# 2  10/08/2024 - ABC solicita orçamento adicional ...
# 3  14/08/2024 - Recepcionado comprovante de pagam...
# 4  17/08/2024 - Vistoria realizada conforme progr...
#
# [5 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 34 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Coluna1                                              27 non-null     int64
#  1   Responsável pelo acionamento ABC                     27 non-null     object
#  2   Data da validação do orçamento                       16 non-null     datetime64[ns]
#  3   ITEM LPU                                             22 non-null     object
#  4   ITEM LPU2                                            22 non-null     float64
#  5   Contratação                                          22 non-null     object
#  6   Previsão estimado de Conclusão                       15 non-null     object
#  7   Identificação                                        22 non-null     object
#  8   Denominação                                          22 non-null     object
#  9   Endereço                                             22 non-null     object
#  10  Cidade                                               22 non-null     object
#  11  UF                                                   22 non-null     object
#  12  STATUS                                               22 non-null     object
#  13  Ação XYZ ou ABC                                      19 non-null     object
#  14  Responsável
# XYZ                                      22 non-null     object
#  15  CNPJ                                                 16 non-null     object
#  16  Matrícula
#                                            4 non-null      float64
#  17
# Área Total do Terreno
#  m²
#                           3 non-null      object
#  18  Área Total Construída
#  m2                            7 non-null      object
#  19  Matrícula com Titularidade ABC
#  (Sim/Não)            4 non-null      object
#  20  Arquivo Executivo em DWG Recepcionado (Sim/ Não/NA)  2 non-null      object
#  21  Data agendada para Vistoria                          1 non-null      datetime64[ns]
#  22  Prazo Previsto para Entrega do Projeto               1 non-null      datetime64[ns]
#  23  Data do Envio do DAEM                                1 non-null      datetime64[ns]
#  24  Data do Protocolo                                    3 non-null      datetime64[ns]
#  25  Nº do Protocolo                                      3 non-null      object
#  26  Data do Envio do Protocolo p/ ABC                    2 non-null      datetime64[ns]
#  27  Código de Consulta site CBMERJ                       1 non-null      object
#  28  Batalhão Responsável
#  ( Telefone e responsável)      1 non-null      object
#  29  Exigência  (Sim/Não)                                 1 non-null      object
#  30  Data da Exigência e prazo p/ Cumprir                 0 non-null      float64
#  31  Observações                                          2 non-null      object
#  32  Data da conclusão do acionamento                     3 non-null      object
#  33  Atualização                                          22 non-null     object
# dtypes: datetime64[ns](6), float64(3), int64(1), object(24)
# memory usage: 7.3+ KB

# %%
df_copy = df.copy()

# %%
df_copy = df_copy[df_copy.loc[:,"Identificação"].isna() == False]

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, 0 to 21
# Data columns (total 34 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Coluna1                                              22 non-null     int64
#  1   Responsável pelo acionamento ABC                     22 non-null     object
#  2   Data da validação do orçamento                       16 non-null     datetime64[ns]
#  3   ITEM LPU                                             22 non-null     object
#  4   ITEM LPU2                                            22 non-null     float64
#  5   Contratação                                          22 non-null     object
#  6   Previsão estimado de Conclusão                       15 non-null     object
#  7   Identificação                                        22 non-null     object
#  8   Denominação                                          22 non-null     object
#  9   Endereço                                             22 non-null     object
#  10  Cidade                                               22 non-null     object
#  11  UF                                                   22 non-null     object
#  12  STATUS                                               22 non-null     object
#  13  Ação XYZ ou ABC                                      19 non-null     object
#  14  Responsável
# XYZ                                      22 non-null     object
#  15  CNPJ                                                 16 non-null     object
#  16  Matrícula
#                                            4 non-null      float64
#  17
# Área Total do Terreno
#  m²
#                           3 non-null      object
#  18  Área Total Construída
#  m2                            7 non-null      object
#  19  Matrícula com Titularidade ABC
#  (Sim/Não)            4 non-null      object
#  20  Arquivo Executivo em DWG Recepcionado (Sim/ Não/NA)  2 non-null      object
#  21  Data agendada para Vistoria                          1 non-null      datetime64[ns]
#  22  Prazo Previsto para Entrega do Projeto               1 non-null      datetime64[ns]
#  23  Data do Envio do DAEM                                1 non-null      datetime64[ns]
#  24  Data do Protocolo                                    3 non-null      datetime64[ns]
#  25  Nº do Protocolo                                      3 non-null      object
#  26  Data do Envio do Protocolo p/ ABC                    2 non-null      datetime64[ns]
#  27  Código de Consulta site CBMERJ                       1 non-null      object
#  28  Batalhão Responsável
#  ( Telefone e responsável)      1 non-null      object
#  29  Exigência  (Sim/Não)                                 1 non-null      object
#  30  Data da Exigência e prazo p/ Cumprir                 0 non-null      float64
#  31  Observações                                          2 non-null      object
#  32  Data da conclusão do acionamento                     3 non-null      object
#  33  Atualização                                          22 non-null     object
# dtypes: datetime64[ns](6), float64(3), int64(1), object(24)
# memory usage: 6.0+ KB

# %%
df_copy.iloc[:5,:17]
# Out:
#    Coluna1 Responsável pelo acionamento ABC Data da validação do orçamento  \
# 0        1                            Maria                     2024-07-02
# 1        2                            Maria                            NaT
# 2        3                            Maria                     2024-07-02
# 3        4                            Maria                     2024-07-17
# 4        5                            Maria                     2024-07-16
#
#                       ITEM LPU  ITEM LPU2  \
# 0   nº 36, 56, 57, 17 e 75. \n    17486.0
# 1   nº 38, 56, 57, 17 e 75. \n    31831.0
# 2            nº 57, 17 e 40.\n     7260.0
# 3            nº 57, 17 e 40.\n     7260.0
# 4                        nº 17     3650.0
#
#                                          Contratação  \
# 0  Aprovação de projeto (LE) + Licença do Corpo d...
# 1  Aprovação de projeto (LE) + Licença do Corpo d...
# 2  Emissão do CA /assinatura da declaração  do re...
# 3  Emissão do CA /assinatura da declaração  do re...
# 4             Laudo Circunstanciado com ART do laudo
#
#                       Previsão estimado de Conclusão Identificação  \
# 0  Entrega do projeto: 31/07/2024. \n6 meses p/ L...         A1122
# 1                                                NaN         A7722
# 2   Entrega do Laudo Circunst. 08/08/2024.\n6 mes...         A6250
# 3   Entrega do Laudo Circunst. 08/08/2024.\n6 mes...         A6254
# 4                                2024-07-25 00:00:00         A9180
#
#                     Denominação                      Endereço   \
# 0      Centro Operacional Alpha        Rua Nova Esperança, 123
# 1             Estação Nova Vila         Avenida Horizonte, 456
# 2  Terminal Logístico Horizonte   Estrada do Sol Nascente, 789
# 3              Armazém Planalto         Rua das Palmeiras, 321
# 4             Polo Estrela Azul  Avenida Estrela do Norte, 654
#
#              Cidade  UF                           STATUS Ação XYZ ou ABC   \
# 0         Vila Nova  RJ        Protocolado \nEm análise               XYZ
# 1      Porto Sereno  RJ  Aguardando aprovação orçamento               ABC
# 2         Vila Nova  RJ                Agendar Vistoria               XYZ
# 3      Porto Sereno  RJ                Agendar Vistoria               XYZ
# 4  Mar do Horizonte  RJ                        concluído              NaN
#
#   Responsável\nXYZ               CNPJ   Matrícula\n
# 0            Julia  12.345.678/0001-91         1234.0
# 1            Julia  50.071.123/0001-00         2345.0
# 2            Julia  12.345.678/0001-92            NaN
# 3            Julia  33.050.789/0001-57            NaN
# 4            Julia  33.050.789/0001-08            NaN

# %%
df_copy.iloc[:5,17:]
# Out:
#   \nÁrea Total do Terreno\n m²\n   Área Total Construída\n m2  \
# 0                       4.236,00m²                     0,00m²
# 1                      10.219,90m²                        NaN
# 2                              NaN                    16,00m²
# 3                              NaN                   716,87m²
# 4                              NaN                 2.355,82m²
#
#   Matrícula com Titularidade ABC\n (Sim/Não)  \
# 0                                       Não
# 1                                       Não
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Arquivo Executivo em DWG Recepcionado (Sim/ Não/NA)  \
# 0                                                Sim
# 1                                               Não
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Data agendada para Vistoria  Prazo Previsto para Entrega do Projeto   \
# 0                   2024-07-18                              2024-08-01
# 1                          NaT                                     NaT
# 2                          NaT                                     NaT
# 3                          NaT                                     NaT
# 4                          NaT                                     NaT
#
#   Data do Envio do DAEM  Data do Protocolo       Nº do Protocolo   \
# 0             2024-07-31         2024-08-13  E45/58231/25634/2025
# 1                    NaT                NaT                   NaN
# 2                    NaT                NaT                   NaN
# 3                    NaT                NaT                   NaN
# 4                    NaT                NaT                   NaN
#
#   Data do Envio do Protocolo p/ ABC Código de Consulta site CBMERJ   \
# 0                        2024-08-13                        MTN5UTNI
# 1                               NaT                             NaN
# 2                               NaT                             NaN
# 3                               NaT                             NaN
# 4                               NaT                             NaN
#
#   Batalhão Responsável\n ( Telefone e responsável) Exigência  (Sim/Não)  \
# 0                            DGST \n(21) 9876-5432                  NaN
# 1                                              NaN                  NaN
# 2                                              NaN                  NaN
# 3                                              NaN                  NaN
# 4                                              NaN                  NaN
#
#    Data da Exigência e prazo p/ Cumprir Observações   \
# 0                                   NaN          NaN
# 1                                   NaN          NaN
# 2                                   NaN          NaN
# 3                                   NaN          NaN
# 4                                   NaN          NaN
#
#   Data da conclusão do acionamento    \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                2024-07-25 00:00:00
#
#                                         Atualização
# 0  16/08/2024 - ABC confirma envio dos documentos...
# 1  12/08/2024 - Emitido alvará provisório referen...
# 2  10/08/2024 - ABC solicita orçamento adicional ...
# 3  14/08/2024 - Recepcionado comprovante de pagam...
# 4  17/08/2024 - Vistoria realizada conforme progr...

# %% [markdown]
# ### As seguintes colunas vão ser as consideradas para a análise dos dados, visto que as outras ou não possuem dados suficientes ou não são relevantes para análise em uma forma geral:
#
#     * Responsável pelo acionamento ABC
#
#     * Data da validação do orçamento
#
#     * ITEM LPU2
#
#     * Contratação
#
#     * Cidade
#
#     * UF
#
#     * STATUS
#
#     * Ação XYZ ou ABC
#
#     * Responsável\nXYZ

# %%
db = df_copy.iloc[:,[1, 2, 4, 5, 10, 11, 12, 13, 14]]

# %%
db
# Out:
#    Responsável pelo acionamento ABC Data da validação do orçamento  ITEM LPU2  \
# 0                             Maria                     2024-07-02    17486.0
# 1                             Maria                            NaT    31831.0
# 2                             Maria                     2024-07-02     7260.0
# 3                             Maria                     2024-07-17     7260.0
# 4                             Maria                     2024-07-16     3650.0
# 5                             Maria                     2024-07-11     1775.0
# 6                             Maria                     2024-07-15     1110.0
# 7                             Maria                            NaT     7260.0
# 8                             Maria                     2024-07-18      211.5
# 9                             Maria                            NaT    26083.0
# 10                            Maria                     2024-08-01    13823.0
# 11                            Maria                     2024-08-05     7260.0
# 12                            Maria                            NaT    13823.0
# 13                            Maria                     2024-08-15    13823.0
# 14                            Maria                            NaT    15248.0
# 15                            Maria                            NaT    15248.0
# 16                            Maria                     2024-08-08     1340.0
# 17                            Maria                     2024-08-08     1340.0
# 18                            Maria                     2024-08-12     1340.0
# 19                            Maria                     2024-08-15    15248.0
# 20                            Maria                     2024-08-13     1340.0
# 21                            Maria                     2024-08-15     1340.0
#
#                                           Contratação             Cidade   UF  \
# 0   Aprovação de projeto (LE) + Licença do Corpo d...          Vila Nova   RJ
# 1   Aprovação de projeto (LE) + Licença do Corpo d...       Porto Sereno   RJ
# 2   Emissão do CA /assinatura da declaração  do re...          Vila Nova   RJ
# 3   Emissão do CA /assinatura da declaração  do re...       Porto Sereno   RJ
# 4              Laudo Circunstanciado com ART do laudo   Mar do Horizonte   RJ
# 5                                    Alvará Sanitário    Vale dos Ventos   RJ
# 6                                     Licença de Obra    Vale dos Ventos   RJ
# 7   Emissão do CA  e Elaboração do Laudo Técnico C...        Nova Aurora   RJ
# 8                                 Revalidação de taxa        Nova Aurora   RJ
# 9   Projeto de bombeiro, LE, CA do prédio \ne loja...       Estrela Azul   RJ
# 10  Aprovação de projeto (LE) + Licença do Corpo d...         Porto Azul   RJ
# 11  Emissão do CA  e Elaboração do Laudo Técnico C...  Vale do Horizonte   RJ
# 12  Aprovação de projeto (LE) + Licença do Corpo d...       Porto Sereno   RJ
# 13  Aprovação de projeto (LE) + Licença do Corpo d...         Vila Verde   RJ
# 14  Aprovação de projeto (LE) + Licença do Corpo d...       Porto Sereno   RJ
# 15  Aprovação de projeto (LE) + Licença do Corpo d...  Jardim das Flores   RJ
# 16  Renovação do Alvará de Funcionamento com a ret...       Porto Sereno   RJ
# 17               Renovação do Alvará de Funcionamento       Costa do Sol  RJ
# 18               Renovação do Alvará de Funcionamento     Vale Encantado  RJ
# 19  Aprovação de projeto (LE) + Licença do Corpo d...         Porto Azul  RJ
# 20                Emissão do Alvará de Funcionamento    Mar do Horizonte   RJ
# 21             Renovação  do Alvará de Funcionamento           Vila Nova   RJ
#
#                              STATUS Ação XYZ ou ABC  Responsável\nXYZ
# 0         Protocolado \nEm análise               XYZ            Julia
# 1   Aguardando aprovação orçamento               ABC            Julia
# 2                 Agendar Vistoria               XYZ            Julia
# 3                 Agendar Vistoria               XYZ            Julia
# 4                         concluído              NaN            Julia
# 5                      Em andamento              XYZ              Ana
# 6    Aguardando  documentos da ABC               ABC            Julia
# 7   Aguardar normalização do CBMERJ              NaN            Julia
# 8                         concluído              NaN            Julia
# 9   Aguardando aprovação orçamento               ABC            Julia
# 10               orçamento aprovado              XYZ              Ana
# 11               orçamento aprovado              ABC              Ana
# 12  Aguardando aprovação orçamento               ABC              Ana
# 13  Aguardando aprovação orçamento               ABC              Ana
# 14  Aguardando aprovação orçamento               ABC              Ana
# 15  Aguardando aprovação orçamento               ABC            Julia
# 16               Orçamento Aprovado              ABC            Julia
# 17                        Concluído              ABC            Julia
# 18               Orçamento Aprovado              ABC            Julia
# 19               Orçamento Aprovado              ABC            Julia
# 20               Orçamento Aprovado              ABC            Julia
# 21               Orçamento Aprovado              ABC            Julia

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, 0 to 21
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Responsável pelo acionamento ABC  22 non-null     object
#  1   Data da validação do orçamento    16 non-null     datetime64[ns]
#  2   ITEM LPU2                         22 non-null     float64
#  3   Contratação                       22 non-null     object
#  4   Cidade                            22 non-null     object
#  5   UF                                22 non-null     object
#  6   STATUS                            22 non-null     object
#  7   Ação XYZ ou ABC                   19 non-null     object
#  8   Responsável
# XYZ                   22 non-null     object
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 1.7+ KB

# %%
for column in db.columns:
    print(db[column].unique())
# Out:
# ['Maria']
# <DatetimeArray>
# ['2024-07-02 00:00:00',                 'NaT', '2024-07-17 00:00:00',
#  '2024-07-16 00:00:00', '2024-07-11 00:00:00', '2024-07-15 00:00:00',
#  '2024-07-18 00:00:00', '2024-08-01 00:00:00', '2024-08-05 00:00:00',
#  '2024-08-15 00:00:00', '2024-08-08 00:00:00', '2024-08-12 00:00:00',
#  '2024-08-13 00:00:00']
# Length: 13, dtype: datetime64[ns]
# [17486.  31831.   7260.   3650.   1775.   1110.    211.5 26083.  13823.
#  15248.   1340. ]
# ['Aprovação de projeto (LE) + Licença do Corpo de bombeiro (CA)'
#  'Emissão do CA /assinatura da declaração  do responsável técnico c/ emissão da ART referente a instalação dos dispositivos preventivos. \n'
#  'Laudo Circunstanciado com ART do laudo' 'Alvará Sanitário'
#  'Licença de Obra'
#  'Emissão do CA  e Elaboração do Laudo Técnico Circusntanciado / emissão da ART referente a instalação dos dispositivos preventivos. \n'
#  'Revalidação de taxa'
#  'Projeto de bombeiro, LE, CA do prédio \ne loja Enel.'
#  'Renovação do Alvará de Funcionamento com a retificação da numeração do logradouro'
#  'Renovação do Alvará de Funcionamento'
#  'Emissão do Alvará de Funcionamento '
#  'Renovação  do Alvará de Funcionamento ']
# ['Vila Nova' 'Porto Sereno' 'Mar do Horizonte' 'Vale dos Ventos'
#  'Nova Aurora' 'Estrela Azul' 'Porto Azul' 'Vale do Horizonte'
#  'Vila Verde' 'Jardim das Flores' 'Costa do Sol' 'Vale Encantado']
# ['RJ' 'RJ ']
# ['Protocolado \nEm análise ' 'Aguardando aprovação orçamento '
#  'Agendar Vistoria ' 'concluído' 'Em andamento'
#  'Aguardando  documentos da ABC ' 'Aguardar normalização do CBMERJ'
#  'orçamento aprovado' 'Orçamento Aprovado' 'Concluído']
# ['XYZ' 'ABC' nan]
# ['Julia' 'Ana']

# %%
db[db.loc[:,"Data da validação do orçamento"].isna() == True]
# Out:
#    Responsável pelo acionamento ABC Data da validação do orçamento  ITEM LPU2  \
# 1                             Maria                            NaT    31831.0
# 7                             Maria                            NaT     7260.0
# 9                             Maria                            NaT    26083.0
# 12                            Maria                            NaT    13823.0
# 14                            Maria                            NaT    15248.0
# 15                            Maria                            NaT    15248.0
#
#                                           Contratação             Cidade  UF  \
# 1   Aprovação de projeto (LE) + Licença do Corpo d...       Porto Sereno  RJ
# 7   Emissão do CA  e Elaboração do Laudo Técnico C...        Nova Aurora  RJ
# 9   Projeto de bombeiro, LE, CA do prédio \ne loja...       Estrela Azul  RJ
# 12  Aprovação de projeto (LE) + Licença do Corpo d...       Porto Sereno  RJ
# 14  Aprovação de projeto (LE) + Licença do Corpo d...       Porto Sereno  RJ
# 15  Aprovação de projeto (LE) + Licença do Corpo d...  Jardim das Flores  RJ
#
#                              STATUS Ação XYZ ou ABC  Responsável\nXYZ
# 1   Aguardando aprovação orçamento               ABC            Julia
# 7   Aguardar normalização do CBMERJ              NaN            Julia
# 9   Aguardando aprovação orçamento               ABC            Julia
# 12  Aguardando aprovação orçamento               ABC              Ana
# 14  Aguardando aprovação orçamento               ABC              Ana
# 15  Aguardando aprovação orçamento               ABC            Julia

# %%
db[db.loc[:,"Ação XYZ ou ABC "].isna() == True]
# Out:
#   Responsável pelo acionamento ABC Data da validação do orçamento  ITEM LPU2  \
# 4                            Maria                     2024-07-16     3650.0
# 7                            Maria                            NaT     7260.0
# 8                            Maria                     2024-07-18      211.5
#
#                                          Contratação            Cidade  UF  \
# 4             Laudo Circunstanciado com ART do laudo  Mar do Horizonte  RJ
# 7  Emissão do CA  e Elaboração do Laudo Técnico C...       Nova Aurora  RJ
# 8                                Revalidação de taxa       Nova Aurora  RJ
#
#                             STATUS Ação XYZ ou ABC  Responsável\nXYZ
# 4                        concluído              NaN            Julia
# 7  Aguardar normalização do CBMERJ              NaN            Julia
# 8                        concluído              NaN            Julia

# %%
df_original = df.copy()
df = db.copy()

# %%
import matplotlib.pyplot as plt

# 1. Distribuição do Status dos Projetos
plt.figure(figsize=(10, 6))
df['STATUS'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribuição do Status dos Projetos')
plt.xlabel('Status')
plt.ylabel('Contagem')
plt.xticks(rotation=45, ha='right')
plt.show()

# 2. Validação de Orçamento ao Longo do Tempo
plt.figure(figsize=(10, 6))
df['Data da validação do orçamento'].value_counts().sort_index().plot(kind='line', marker='o', color='orange')
plt.title('Validação de Orçamento ao Longo do Tempo')
plt.xlabel('Data')
plt.ylabel('Quantidade de Validações')
plt.grid(True)
plt.show()

# 3. Contratação por Cidade
plt.figure(figsize=(10, 6))
df['Cidade'].value_counts().plot(kind='bar', color='purple')
plt.title('Distribuição de Contratações por Cidade')
plt.xlabel('Cidade')
plt.ylabel('Contagem')
plt.xticks(rotation=90)
plt.show()
